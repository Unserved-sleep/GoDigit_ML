# %%
import matplotlib.pyplot as plt
import numpy as np
from prompt_toolkit.layout import layout

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])

# %%
fig = plt.figure()

# %%
fig, ax = plt.subplots()
fig, axs = plt.subplots(2, 2)

# %%
fig, axs = plt.subplot_mosaic([["left", "right_top"], ["left", "right_bottom"]])

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
np.random.seed(1)
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}

data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
# Out:
# Text(0, 0.5, 'entry b')

# %%
x = np.linspace(0, 2, 100)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple Plot")
ax.legend()

# %%
x = np.linspace(0, 2, 100)

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()

# %%
def my_plotter(data1, data2, param_dict):
    out = plt.plot(data1, data2, **param_dict)
    return out

# %%
data1, data2, data3, data4 = np.random.rand(4, 100)
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.subplot(2, 2, 1)
my_plotter(data1, data2, {'marker': 'x'})
plt.subplot(2, 2, 2)
my_plotter(data3, data4, {'marker': 'o'})

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
x = np.arange(len(data1))
plt.plot(x, np.cumsum(data1), color='red', linestyle='dashed', linewidth=2)
plt.plot(x, np.cumsum(data2), color='blue', linestyle='dotted', linewidth=2)

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.scatter(data1, data2, s=50, facecolors='C0', edgecolors='k')

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(data1, 'o', label='data1')
plt.plot(data2, 'd', label='data2')
plt.plot(data3, 's', label='data3')
plt.plot(data4, 'v', label='data4')
plt.legend(loc='lower right')

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
plt.figure(figsize=(5, 2.7), layout='constrained')
n, bins, patches = plt.hist(x, 50, facecolor='g', alpha=0.75, density=True)
plt.xlabel('Length')
plt.ylabel('Probability')
plt.title('Histogram')
plt.text(75, .025, r'$\mu=115,\ \sigma=15$')
plt.axis([55, 175, 0, 0.03])
plt.grid(True)

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
plt.plot(t, s, lw=2)
plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05))
plt.ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.plot(np.arange(len(data1)), data1, label='data1')
plt.plot(np.arange(len(data2)), data2, label='data2')
plt.plot(np.arange(len(data3)), data3, 'd', label='data3')
plt.legend()

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
xdata = np.arange(len(data1))
data = 10**data1
plt.subplot(1, 2, 1)
plt.plot(xdata, data)
plt.subplot(1, 2, 2)
plt.yscale('log')
plt.plot(xdata, data)

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
plt.subplot(2,1,1)
plt.title('Automatic ticks')
plt.plot(xdata, data1)
plt.subplot(2,1,2)
plt.plot(xdata, data1)

# %%
from matplotlib.dates import ConciseDateFormatter

plt.figure(figsize=(5, 2.7), layout='constrained')
dates = np.arange(np.datetime64('2021-11-15'), np.datetime64('2021-12-25'), np.timedelta64(1, 'h'))
data = np.cumsum(np.random.randn(len(dates)))
plt.plot(dates, data)
plt.gca().xaxis.set_major_formatter(ConciseDateFormatter(plt.gca().xaxis.get_major_locator()))

# %%
plt.figure(figsize=(5, 2.7), layout='constrained')
categories = ['turnips', 'rutabaga', 'cucumber', 'pumpkins']
plt.bar(categories, np.random.rand(len(categories)))
# Out:
# <BarContainer object of 4 artists>

# %%
plt.figure(figsize=(7, 2.7), layout='constrained')
plt.subplot(1, 2, 1)
l1, = plt.plot(t, s)
ax2 = plt.gca().twinx()
l2, = plt.plot(t, range(len(t)), 'C1')
plt.legend([l1, l2], ['Sine (left)', 'Straight (right)'])

plt.subplot(1, 2, 2)
plt.plot(t, s)
plt.xlabel('Angle [rad]')
ax4 = plt.gca().secondary_xaxis(
    'top',
    functions=(np.rad2deg, np.deg2rad)
)
ax4.set_xlabel('Angle [°]')
# Out:
# Text(0.5, 0, 'Angle [°]')

# %%
from matplotlib.colors import LogNorm
X, Y = np.meshgrid(np.linspace(-3, 3, 100), np.linspace(-3, 3, 100))
Z = (1- X/2 + X**2 + Y**3) * np.exp(-X**2 - Y**2)

plt.figure(figsize=(5, 2.7), layout='constrained')
plt.subplot(2, 2, 1)
pc = plt.pcolormesh(
    X, Y, Z,
    vmin=-1,
    vmax=1,
    cmap='RdBu_r'
)
plt.colorbar(pc)
plt.title('pcolormesh()')


plt.subplot(2, 2, 2)
co = plt.contourf(
    X, Y, Z,
    levels=np.linspace(-1.25, 1.25, 11)
)
plt.colorbar(co)
plt.title('contourf()')

plt.subplot(2, 2, 3)
pc = plt.imshow(
    Z**2 * 100,
    cmap='plasma',
    norm=LogNorm(vmin=0.01, vmax=100)
)
plt.colorbar(pc, extend='both')
plt.title('imshow() with LogNorm()')

plt.subplot(2, 2, 4)
pc = plt.scatter(
    data1,
    data2,
    c=data3,
    cmap='RdBu_r'
)
plt.colorbar(pc, extend='both')
plt.title('scatter()')
# Out:
# Text(0.5, 1.0, 'scatter()')

# %%
import seaborn as sns

sns.set_theme()
sns.relplot(x=data1, y=data2, hue=data3, size=data4, sizes=(40, 400))
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
import pandas as pd
df = pd.DataFrame({
    "x": np.arange(20),
    "y": np.random.randint(10, 100, 20),
    "group": np.random.choice(["A", "B"], 20),
    "magnitude": np.random.randint(1, 10, 20),
    "align": np.random.choice(["left", "right"], 20)
})

sns.relplot(
    data=df, kind="line",
    x="x", y="y", col="group",
    hue="magnitude", style="align",
)
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(
    data=df, x="x", y="y", col="group",
    hue="magnitude")
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(
    data=df, x="y", col="group",
    hue="magnitude", kind="kde")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34532\2695867740.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34532\2695867740.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34532\2695867740.py:1: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.displot(
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(
    data=df, x="y", col="group",
    hue="magnitude", kind="hist")
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(
    data=df, x="group", y="y",
    hue="magnitude", kind="box")
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(
    data=df, x="group", y="y",
    hue="magnitude", kind="violin")
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(
    data=df, x="group", y="y",
    hue="magnitude", kind="bar")
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.jointplot(
    data=df, x="x", y="y",
    hue="group")

# %%
sns.jointplot(
    data=df, hue="group",
    x="x", y="y",
    kind="kde")

# %%
sns.pairplot(
    data=df, hue="group",
    diag_kind="kde")
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.PairGrid(df, hue="group", corner=True)
g.map_lower(sns.kdeplot, hue=None, levels=5, color=".2")
g.map_lower(sns.scatterplot, marker="+")
g.map_diag(sns.histplot, element="step", linewidth=0, kde=True)
g.add_legend(frameon=True)
g.legend.set_bbox_to_anchor((.61, .6))

# %%
sns.relplot(
    data=df, x="x", y="y",
    hue="group", size="magnitude",
    sizes=(40, 400), alpha=.5)
# Out:
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme(style="ticks", font_scale=1.25)
g = sns.relplot(
    data=df, x="x", y="y",
    hue="group", size="magnitude",
    sizes=(40, 400), alpha=.5, markers="X", palette=sns.color_palette("hls", 10))
g.set_axis_labels("X Axis", "Y Axis")
g.legend.set_title("Group")
g.figure.set_size_inches(5, 2.7)
g.ax.margins(.15)
g.despine(trim=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_34532\3566751096.py:2: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   g = sns.relplot(
# C:\Users\Admin\miniconda3\envs\untitled\lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
